# %% [markdown]
# # K-means Clustering K均值聚类

# %% [markdown]
# ### Import resources and display image

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %matplotlib inline

# Read in the image
## TODO: Check out the images directory to see other images you can work with
# And select one!
image = cv2.imread('images/monarch.jpg')

# Change color to RGB (from BGR)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image)

# %% [markdown]
# ### Prepare data for k-means 为k-means准备数据

# %%
# Reshape image into a 2D array of pixels and 3 color values (RGB) 将图像重塑为2D像素阵列和3个颜色值（RGB）
pixel_vals = image.reshape((-1,3))

# Convert to float type
pixel_vals = np.float32(pixel_vals)

# %% [markdown]
# ### Implement k-means clustering 实施k-means聚类

# %%
# define stopping criteria 定义停止标准
# you can change the number of max iterations for faster convergence! 您可以更改最大迭代次数以加快收敛速度！
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 100, 0.2)

## TODO: Select a value for k 
# then perform k-means clustering 然后执行k-means聚类
k = 3
retval, labels, centers = cv2.kmeans(pixel_vals, k, None, criteria, 10, cv2.KMEANS_RANDOM_CENTERS)

# convert data into 8-bit values
centers = np.uint8(centers)
segmented_data = centers[labels.flatten()]

# reshape data into the original image dimensions
segmented_image = segmented_data.reshape((image.shape))
labels_reshape = labels.reshape(image.shape[0], image.shape[1])

plt.imshow(segmented_image)

# %%
## TODO: Visualize one segment, try to find which is the leaves, background, etc! 可视化一个片段，尝试找到哪个是叶子，背景等！
plt.imshow(labels_reshape==0, cmap='gray')

# %%
# mask an image segment by cluster 按群集屏蔽图像

cluster = 0 # the first cluster 第一个集群

masked_image = np.copy(image)
# turn the mask green!
masked_image[labels_reshape == cluster] = [0, 255, 0]

plt.imshow(masked_image)

# %% [markdown]
# ![_auto_0](attachment:_auto_0)

# %%
'''
完成时间：2019-5-9
'''
